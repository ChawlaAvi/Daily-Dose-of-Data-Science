# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Why Correlation (and Other Statistics) Can Be Misleading.
#
# Post Link: [Substack](https://avichawla.substack.com/p/why-correlation-and-other-statistics)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/posts/avi-chawla_python-datascience-statistics-activity-7003686582763294720-sphP?utm_source=share&utm_medium=member_desktop)

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df_with_outliers = pd.read_csv("../_Datasets/Correlation_example.csv")
df_with_outliers.head()
# Out:
#           x         y
# 0  0.704806 -0.468064
# 1 -1.308381 -3.565576
# 2 -0.190285 -2.504855
# 3  0.664763  0.643189
# 4  0.291005  0.873306

# %%
df_without_outliers = df_with_outliers.loc[:47]

# %%
df_without_outliers.plot(kind='scatter',x='x', y='y')
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>

# %%
sns.lmplot(x = "x", y = "y", data = df_without_outliers, ci = None)

# %%
sns.lmplot(x = "x", y = "y", data = df_with_outliers, ci = None)
