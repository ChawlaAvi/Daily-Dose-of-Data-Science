# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Deep Learning Network Debugging Made Easy
#
# Post Link: [Substack](https://avichawla.substack.com/p/deep-learning-network-debugging-made)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:activity:7006932462995976192/)

# %%
# !pip install tensor-sensor
# Out:
# Requirement already satisfied: tensor-sensor in /Users/avi/anaconda3/lib/python3.9/site-packages (1.0)
# Requirement already satisfied: matplotlib in /Users/avi/anaconda3/lib/python3.9/site-packages (from tensor-sensor) (3.5.3)
# Requirement already satisfied: graphviz>=0.14.1 in /Users/avi/anaconda3/lib/python3.9/site-packages (from tensor-sensor) (0.20.1)
# Requirement already satisfied: IPython in /Users/avi/anaconda3/lib/python3.9/site-packages (from tensor-sensor) (8.2.0)
# Requirement already satisfied: numpy in /Users/avi/anaconda3/lib/python3.9/site-packages (from tensor-sensor) (1.21.5)
# Requirement already satisfied: pygments>=2.4.0 in /Users/avi/anaconda3/lib/python3.9/site-packages (from IPython->tensor-sensor) (2.11.2)
# Requirement already satisfied: matplotlib-inline in /Users/avi/anaconda3/lib/python3.9/site-packages (from IPython->tensor-sensor) (0.1.2)
# Requirement already satisfied: stack-data in /Users/avi/anaconda3/lib/python3.9/site-packages (from IPython->tensor-sensor) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/avi/anaconda3/lib/python3.9/site-packages (from IPython->tensor-sensor) (4.8.0)
# Requirement already satisfied: appnope in /Users/avi/anaconda3/lib/python3.9/site-packages (from IPython->tensor-sensor) (0.1.2)
# Requirement already satisfied: decorator in /Users/avi/anaconda3/lib/python3.9/site-packages (from IPython->tensor-sensor) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /Users/avi/anaconda3/lib/python3.9/site-packages (from IPython->tensor-sensor) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/avi/anaconda3/lib/python3.9/site-packages (from IPython->tensor-sensor) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/avi/anaconda3/lib/python3.9/site-packages (from IPython->tensor-sensor) (0.7.5)
# Requirement already satisfied: backcall in /Users/avi/anaconda3/lib/python3.9/site-packages (from IPython->tensor-sensor) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/avi/anaconda3/lib/python3.9/site-packages (from IPython->tensor-sensor) (61.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/avi/anaconda3/lib/python3.9/site-packages (from IPython->tensor-sensor) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/avi/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->IPython->tensor-sensor) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/avi/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->IPython->tensor-sensor) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/avi/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->tensor-sensor) (0.2.5)
# Requirement already satisfied: cycler>=0.10 in /Users/avi/anaconda3/lib/python3.9/site-packages (from matplotlib->tensor-sensor) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/avi/anaconda3/lib/python3.9/site-packages (from matplotlib->tensor-sensor) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /Users/avi/anaconda3/lib/python3.9/site-packages (from matplotlib->tensor-sensor) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/avi/anaconda3/lib/python3.9/site-packages (from matplotlib->tensor-sensor) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/avi/anaconda3/lib/python3.9/site-packages (from matplotlib->tensor-sensor) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/avi/anaconda3/lib/python3.9/site-packages (from matplotlib->tensor-sensor) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/avi/anaconda3/lib/python3.9/site-packages (from matplotlib->tensor-sensor) (4.25.0)
# Requirement already satisfied: six>=1.5 in /Users/avi/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->tensor-sensor) (1.16.0)
# Requirement already satisfied: pure-eval in /Users/avi/anaconda3/lib/python3.9/site-packages (from stack-data->IPython->tensor-sensor) (0.2.2)
# Requirement already satisfied: asttokens in /Users/avi/anaconda3/lib/python3.9/site-packages (from stack-data->IPython->tensor-sensor) (2.0.5)
# Requirement already satisfied: executing in /Users/avi/anaconda3/lib/python3.9/site-packages (from stack-data->IPython->tensor-sensor) (0.8.3)

# %%
import torch
import tsensor

# %%
n = 200                          # number of instances
d = 764                          # number of instance features
n_neurons = 100                  # how many neurons in this layer?
batch_size = 10                  # how many records per batch?
n_batches = n // batch_size

W = torch.rand(n_neurons,d)
b = torch.rand(n_neurons,1)
X = torch.rand(n_batches,batch_size, d)

with tsensor.explain():
    for i in range(n_batches):
        batch = X[i,:,:]
        Y = torch.matmul(W, batch.T) + b

# %%
W = torch.rand(size=(2000,2000), dtype=torch.float64)
b = torch.rand(size=(2000,1), dtype=torch.float64)
h = torch.zeros(size=(1_000_000,), dtype=int)
x = torch.rand(size=(2000,1))
z = torch.rand(size=(2000,1), dtype=torch.complex64)


with tsensor.explain() as c:
    output = W@b + (h+3).dot(h) + z
