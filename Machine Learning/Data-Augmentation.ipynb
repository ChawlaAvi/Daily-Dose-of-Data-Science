# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # An Effective Yet Underrated Technique To Improve Model Performance
#
# Post Link: [Substack](https://avichawla.substack.com/p/an-effective-yet-underrated-technique)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:activity:7027594494862594048/)

# %%
# !pip install imgaug

# %%
import numpy as np
import imgaug as ia
import imgaug.augmenters as iaa


ia.seed(1)

# %%
images = np.array(
    [ia.quokka(size=(256, 256)) for _ in range(4)],
    dtype=np.uint8)

# %%
fig, axs = plt.subplots(2, 2, figsize=(3, 3))
for ax, image in zip(axs.flat, images):
    ax.imshow(image, cmap='gray')
    ax.axis('off')
plt.subplots_adjust(hspace=0, wspace=0)
plt.show()

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5), # horizontal flips
    iaa.Rotate(rotate=(-5,-20), ),
    iaa.Affine(
        scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
        rotate=(-25, 25),
        shear=(-8, 8))
], random_order=True) # apply augmenters in random order

# %%
images_aug = seq(images=images)

# %%
fig, axs = plt.subplots(2, 2, figsize=(3, 3))
for ax, image in zip(axs.flat, images_aug):
    ax.imshow(image, cmap='gray')
    ax.axis('off')
plt.subplots_adjust(hspace=0, wspace=0)
plt.show()
