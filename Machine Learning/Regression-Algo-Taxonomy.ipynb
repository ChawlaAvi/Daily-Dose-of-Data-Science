# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # The Taxonomy Of Regression Algorithms That Many Don't Bother To Remember
#
# Post Link: [Substack](https://avichawla.substack.com/p/the-taxonomy-of-regression-algorithms)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7058723746852798465/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1652957983712657419)

# %% [markdown]
# ![image.png](attachment:image.png)
