# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # A Visual Guide to Stochastic, Mini-batch, and Batch Gradient Descent
#
# Post Link: [Substack](https://avichawla.substack.com/p/a-visual-guide-to-stochastic-mini)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7060179867497078784)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1654414169070882817)

# %% [markdown]
# ![image.png](attachment:image.png)
