# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # 10 Most Common (and Must-Know) Loss Functions in ML
#
# Post Link: [Substack](https://www.blog.dailydoseofds.com/p/10-most-common-and-must-know-loss)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7077588800645869568/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1671823032162082817/)

# %% [markdown]
# ![image.png](attachment:image.png)
