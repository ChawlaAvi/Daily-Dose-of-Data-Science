# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Random Forest May Not Need An Explicit Validation Set For Evaluation
#
# Post Link: [Substack](https://www.blog.dailydoseofds.com/p/random-forest-may-not-need-an-explicit)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7079031017059028992/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1673265319052300290)

# %% [markdown]
# ![image.png](attachment:image.png)
