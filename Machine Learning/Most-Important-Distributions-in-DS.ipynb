# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Nine Most Important Distributions in Data Science
#
# Post Link: [Substack](https://www.blog.dailydoseofds.com/p/nine-most-important-distributions)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7072495577451704320/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1666729864504696832)

# %% [markdown]
# ![image.png](attachment:image.png)
