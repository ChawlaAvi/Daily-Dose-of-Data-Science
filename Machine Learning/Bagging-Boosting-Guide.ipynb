# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # A Visual and Overly Simplified Guide To Bagging and Boosting
#
# Post Link: [Substack](https://www.blog.dailydoseofds.com/p/a-visual-and-overly-simplified-guide-4b1)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7077962278830022656)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1672196554013265920)

# %% [markdown]
# ![image.png](attachment:image.png)
