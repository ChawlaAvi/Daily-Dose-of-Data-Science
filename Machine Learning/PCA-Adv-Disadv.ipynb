# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # The Advantages and Disadvantages of PCA To Consider Before Using It
#
# Post Link: [Substack](https://avichawla.substack.com/p/the-advantages-and-disadvantages)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7061995131104559104/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1656229356790751232)

# %% [markdown]
# ![image.png](attachment:image.png)
