# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # The Limitation of PCA Which Many Folks Often Ignore
#
# Post Link: [Substack](https://avichawla.substack.com/p/the-limitation-of-pca-which-many)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:activity:7059458534412795904/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1653692840805904385)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.datasets import make_moons
from sklearn.decomposition import KernelPCA, PCA

sns.set()

# %%
colors = ['#fe7c73', '#2471A3']

# %% [markdown]
# ## Dataset

# %%
X, y = make_moons(n_samples=500, noise=0.03)

fig, ax = plt.subplots()

plt.scatter(X[:, 0], X[:, 1], c=[colors[i] for i in y])
ax.set_xticklabels([])
ax.set_yticklabels([])
plt.show()

# %% [markdown]
# # PCA

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

fig, ax = plt.subplots()

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=[colors[i] for i in y])

ax.set_xticklabels([])
ax.set_yticklabels([])
plt.show()

# %% [markdown]
# # Kernel PCA

# %%
kpca = KernelPCA(n_components=2, kernel='rbf', gamma=14)
X_kpca = kpca.fit_transform(X)

fig, ax = plt.subplots()

plt.scatter(X_kpca[:, 0], X_kpca[:, 1], c=[colors[i] for i in y])
ax.set_xticklabels([])
ax.set_yticklabels([])
plt.show()
