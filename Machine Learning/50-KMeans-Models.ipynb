# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # A (Highly) Important Point to Consider Before You Use KMeans Next Time
#
# Post Link: [Substack](https://avichawla.substack.com/p/a-highly-important-point-to-consider)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:activity:7047521375959326721/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1641766436509999106)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
df = pd.read_csv("../_Datasets/25_cluster_data.csv")
X = df.values
df.head()
# Out:
#          x1        x2
# 0  0.111664  0.090023
# 1  0.085615  0.106970
# 2  0.114612  0.020423
# 3  0.075775  0.136066
# 4  0.093122  0.152457

# %%
fig, ax = plt.subplots(figsize = (9, 6))

plt.scatter(X[:, 0], X[:, 1], c = '#46C7C7')
plt.title("Dataset", fontsize = 30, fontweight="bold")
ax.set_xticklabels([])
ax.set_yticklabels([]);

# %%
k=25 ## number of centroids

# %%
# run k-means from scikit-learn with random initialization
km=KMeans(n_clusters=k, init = "random")
km.fit(X)

# run k-means++ from scikit-learn
kmp=KMeans(n_clusters=k)
kmp.fit(X)

fig, ax = plt.subplots(figsize = (9, 6))

plt.scatter(X[:, 0], X[:, 1], label='Data Point', c=km.labels_, cmap='GnBu')
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], c='red', marker='o', label='Centroid', s = 100)
plt.title("KMeans", fontsize = 40, fontweight="bold")
plt.legend(loc = "upper right")
plt.ylim(0.00, 1.05)
ax.set_xticklabels([])
ax.set_yticklabels([])
plt.show()

fig, ax = plt.subplots(figsize = (9, 6))

plt.scatter(X[:, 0], X[:, 1], label='Data Point', c=kmp.labels_, cmap='GnBu')
plt.scatter(kmp.cluster_centers_[:, 0], kmp.cluster_centers_[:, 1], c='red', marker='o', label='Centroid', s = 100)
plt.title("KMeans++", fontsize = 40, fontweight="bold")
plt.legend(loc = "upper right")
plt.ylim(0.00, 1.05)
ax.set_xticklabels([])
ax.set_yticklabels([])
plt.show()
