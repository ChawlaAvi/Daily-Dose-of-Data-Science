# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # 9 Most Important Plots in Data Science
#
# Post Link: [Substack](https://www.blog.dailydoseofds.com/p/9-most-important-plots-in-data-science)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7067783208020393985/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1662017501155270656)

# %% [markdown]
# ![image.png](attachment:image.png)
