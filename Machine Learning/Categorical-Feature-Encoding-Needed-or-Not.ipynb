# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Is Categorical Feature Encoding Always Necessary Before Training ML Models?
#
# Post Link: [Substack](https://www.blog.dailydoseofds.com/p/is-categorical-feature-encoding-always)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7067430011984576512/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1661664288715440130)

# %% [markdown]
# ![image.png](attachment:image.png)
