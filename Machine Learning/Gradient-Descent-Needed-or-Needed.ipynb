# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Does Every ML Algorithm Rely on Gradient Descent?
#
# Post Link: [Substack](https://www.blog.dailydoseofds.com/p/does-every-ml-algorithm-rely-on-gradient)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7071416723677036545/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1665651024160227328)

# %% [markdown]
# ![image.png](attachment:image.png)
