# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # A Reliable and Efficient Technique To Measure Feature Importance
#
# Post Link: [Substack](https://www.blog.dailydoseofds.com/p/a-reliable-and-efficient-technique)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7071790440408039424/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1666024742074105860)

# %% [markdown]
# ![image.png](attachment:image.png)
