# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Is Data Normalization Always Necessary Before Training ML Models?
#
# Post Link: [Substack](https://avichawla.substack.com/p/is-data-normalization-always-necessary)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7061278460991672320/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1655512741459681281)

# %% [markdown]
# ![image.png](attachment:image.png)
