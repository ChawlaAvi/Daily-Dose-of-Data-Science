# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # The Ultimate Categorization of Performance Metrics in ML
#
# Post Link: [Substack](https://www.blog.dailydoseofds.com/p/the-ultimate-categorization-of-performance)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7069225575558656000/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1663459868152565761)

# %% [markdown]
# ![image.png](attachment:image.png)
