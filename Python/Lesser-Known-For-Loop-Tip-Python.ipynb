# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Most Python Programmers Don't Know This About Python For-loops
#
# Post Link: [Substack](https://avichawla.substack.com/p/most-python-programmers-dont-know)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:activity:7033749385012207616/)

# %%
for num in range(5):
    print(f"num = {num}")
    num = 10
# Out:
# num = 0
# num = 1
# num = 2
# num = 3
# num = 4
