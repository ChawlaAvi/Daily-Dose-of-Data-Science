# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # What Does The Google Styling Guide Say About Imports
#
# Post Link: [Substack](https://avichawla.substack.com/p/what-does-the-google-styling-guide)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7063088012720562176/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1657322306702565376)

# %% [markdown]
# ![image.png](attachment:image.png)
