# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # 7 Elegant Usages of Underscore in Python
#
# Post Link: [Substack](https://www.blog.dailydoseofds.com/p/7-elegant-usages-of-underscore-in)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:ugcPost:7079389534060183552)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1673623924456796160)

# %% [markdown]
# ### Retrieve the last computed value

# %%
5+10
# Out:
# 15

# %%
_
# Out:
# 15

# %% [markdown]
# ### Digit separator

# %%
10000000000000
# Out:
# 10000000000000

# %%
10_000_000_000_000
# Out:
# 10000000000000

# %% [markdown]
# ### Placeholder for loop variable

# %%
for _ in range(10):
    pass

# %% [markdown]
# ### Single leading underscore to indicate variables for internal use

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Single trailing underscore to avoid conflict with keywords

# %%
def foo(class_ = "object"):
    pass

# %% [markdown]
# ### Double leading underscores to invoke name mangling

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Double leading and trailing underscores to write magic methods

# %% [markdown]
# ![image.png](attachment:image.png)
