# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Run Python Project Directory As A Script
#
# Post Link: [Substack](https://avichawla.substack.com/p/run-python-project-directory-as-a)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/posts/avi-chawla_python-activity-6992432444817747968-sQpe?utm_source=share&utm_medium=member_desktop)

# %% [markdown]
# ![image.png](attachment:image.png)
