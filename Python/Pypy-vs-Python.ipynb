# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Improve Python Run-time Without Changing A Single Line of Code
#
# Post Link: [Substack](https://www.blog.dailydoseofds.com/p/improve-python-run-time-without-changing)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:activity:7065607926740074496/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1659842214892130304)

# %% [markdown]
# ![image.png](attachment:image.png)
