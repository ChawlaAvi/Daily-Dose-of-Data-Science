# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Execute Python Project Directory as a Script
#
# Post Link: [Substack](https://www.blog.dailydoseofds.com/p/execute-python-project-directory)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7068490297269190656/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1662724444211798018)

# %% [markdown]
# ![image.png](attachment:image.png)
