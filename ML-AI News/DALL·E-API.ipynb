# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Now You Can Use DALL·E With OpenAI API
#
# Post Link: [Substack](https://avichawla.substack.com/p/now-you-can-use-dalle-with-openai)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/posts/avi-chawla_machinelearning-openai-python-activity-6994244975412568064-kZqA?utm_source=share&utm_medium=member_desktop)

# %% [markdown]
# ![image.png](attachment:image.png)
