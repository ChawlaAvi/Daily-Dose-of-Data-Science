# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a data science oriented publication on Substack. It brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)

# %% [markdown]
# # Handle Missing Data With Missingno
#
# Post Link: [Substack](https://avichawla.substack.com/p/handle-missing-data-with-missingno)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/posts/avi-chawla_dataanalysis-python-pandas-activity-6983355299936002049-ivUw)

# %%
# !pip install missingno

# %%
import pandas as pd
import missingno as msno

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ResidentMario/missingno-data/master/nyc_collision_factors.csv")
df.head()
# Out:
#          DATE      TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  11/10/2016  16:11:00   BROOKLYN   11208.0  40.662514 -73.872007
# 1  11/10/2016  05:11:00  MANHATTAN   10013.0  40.721323 -74.008344
# 2  04/16/2016  09:15:00   BROOKLYN   11201.0  40.687999 -73.997563
# 3  04/15/2016  10:20:00     QUEENS   11375.0  40.719228 -73.854542
# 4  04/15/2016  10:35:00   BROOKLYN   11210.0  40.632147 -73.952731
#
#                     LOCATION  ON STREET NAME CROSS STREET NAME  \
# 0  (40.6625139, -73.8720068)  WORTMAN AVENUE    MONTAUK AVENUE
# 1  (40.7213228, -74.0083444)   HUBERT STREET     HUDSON STREET
# 2  (40.6879989, -73.9975625)    HENRY STREET     WARREN STREET
# 3  (40.7192276, -73.8545422)             NaN               NaN
# 4  (40.6321467, -73.9527315)  BEDFORD AVENUE       CAMPUS ROAD
#
#       OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 1  \
# 0                 NaN  ...  Failure to Yield Right-of-Way
# 1                 NaN  ...  Failure to Yield Right-of-Way
# ...

# %% [markdown]
# ### Missing values with Pandas

# %%
print(df.isnull().sum())
# Out:
# DATE                                0
# TIME                                0
# BOROUGH                           383
# ZIP CODE                          384
# LATITUDE                            0
# LONGITUDE                           0
# LOCATION                            0
# ON STREET NAME                   1065
# CROSS STREET NAME                1137
# OFF STREET NAME                  6542
# NUMBER OF PERSONS INJURED           0
# NUMBER OF PERSONS KILLED            0
# NUMBER OF PEDESTRIANS INJURED       0
# NUMBER OF PEDESTRIANS KILLED        0
# NUMBER OF CYCLISTS INJURED       7303
# NUMBER OF CYCLISTS KILLED        7303
# CONTRIBUTING FACTOR VEHICLE 1       0
# CONTRIBUTING FACTOR VEHICLE 2    1085
# CONTRIBUTING FACTOR VEHICLE 3    7000
# CONTRIBUTING FACTOR VEHICLE 4    7244
# CONTRIBUTING FACTOR VEHICLE 5    7289
# VEHICLE TYPE CODE 1                58
# VEHICLE TYPE CODE 2              1520
# VEHICLE TYPE CODE 3              7019
# VEHICLE TYPE CODE 4              7249
# ...

# %% [markdown]
# ### Missing values with Missingno

# %%
msno.matrix(df)
# Out:
# <AxesSubplot: >
