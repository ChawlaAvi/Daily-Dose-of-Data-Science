# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Why Sklearn's Linear Regression Has No Hyperparameters?
#
# Post Link: [Substack](https://www.blog.dailydoseofds.com/p/why-sklearns-linear-regression-has)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7071051326675197952/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1665285641452548097)

# %% [markdown]
# ![image.png](attachment:image.png)
