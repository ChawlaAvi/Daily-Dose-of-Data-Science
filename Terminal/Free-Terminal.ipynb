# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Most Command-line Users Don't Know This Cool Trick About Using Terminals
#
# Post Link: [Substack](https://avichawla.substack.com/p/most-command-line-users-dont-know)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:ugcPost:7035559197928796160/)

# %%
from IPython.display import Video

# %%
Video("../_Extras/terminal-bg-tasks.mp4", width = 700)
# Out:
# <video src="../_Extras/terminal-bg-tasks.mp4" controls  width="700" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ![image.png](attachment:image.png)
