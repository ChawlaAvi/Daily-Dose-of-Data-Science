# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Simple One-Liners to Preview a Decision Tree Using Sklearn
#
# Post Link: [Substack](https://avichawla.substack.com/p/simple-one-liners-to-preview-a-decision)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:share:7029395906932162560/)

# %%
import seaborn as sns
df = sns.load_dataset("iris")
X = df.iloc[:, [0,1,2,3]].values
y = df.iloc[:,[-1]].values

# %%
df["species"] = pd.factorize(df["species"])[0]

# %%
features = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
classes = ['setosa', 'versicolor', 'virginica']

# %%
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree, export_text

# %%
my_tree = DecisionTreeClassifier(max_depth=2)
my_tree.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %% [markdown]
# ## Method 1

# %%
plot_tree(my_tree, feature_names=features, class_names=classes, filled=True);

# %% [markdown]
# ## Method 2

# %%
print(export_text(my_tree, feature_names=features))
# Out:
# |--- petal_width <= 0.80
# |   |--- class: setosa
# |--- petal_width >  0.80
# |   |--- petal_width <= 1.75
# |   |   |--- class: versicolor
# |   |--- petal_width >  1.75
# |   |   |--- class: virginica
