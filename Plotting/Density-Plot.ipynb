# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Density Plot As A Richer Alternative to Scatter Plot
#
# Post Link: [Substack](https://avichawla.substack.com/p/density-plot-as-a-richer-alternative)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:activity:7021077124845346817/)

# %%
import pandas as pd
import seaborn as sns

# %%
data = []
n = 1000
x = np.random.standard_normal(n)
y = 2.0 + 3.0 * x + 4.0 * np.random.standard_normal(n)
df = pd.DataFrame()
df['x'] = x
df['y'] = y

# %% [markdown]
# ### Scatter Plot

# %%
sns.scatterplot(x=df.x, y=df.y)
plt.show()

# %% [markdown]
# ### Density Plot

# %%
sns.kdeplot(x=df.x, y=df.y, cmap="Blues", shade=True)
plt.show()
