# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Don't Overuse Scatter, Line and Bar Plots. Try These Four Elegant Alternatives.
#
# Post Link: [Substack](https://www.blog.dailydoseofds.com/p/dont-overuse-scatter-line-and-bar)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/posts/avi-chawla_machinelearning-datascience-activity-7080891049153372160-5_8U?utm_source=share&utm_medium=member_desktop)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1675124892184838146)

# %% [markdown]
# ## Scatter

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Bar

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Line/Bar

# %% [markdown]
# ![image.png](attachment:image.png)
