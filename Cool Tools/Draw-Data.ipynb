# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Draw The Data You Are Looking For In Seconds
#
# Post Link: [Substack](https://avichawla.substack.com/p/draw-the-data-you-are-looking-for)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:activity:7031574749436649472/)

# %%
# !pip install drawdata

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import seaborn as sns

from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats('svg')

# %%
from drawdata import draw_scatter
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df = pd.read_clipboard(sep=",")
sns.relplot(data=df, x='x', y='y', hue='z')
