# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Importing Modules Made Easy with Pyforest
#
#
# Post Link: [Substack](https://avichawla.substack.com/p/importing-modules-made-easy-with)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/posts/avi-chawla_python-datascience-activity-6996067478309101568-lVgl?utm_source=share&utm_medium=member_desktop)

# %%
# !pip install pyforest

# %% [markdown]
# ![image.png](attachment:image.png)
