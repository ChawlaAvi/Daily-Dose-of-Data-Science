# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Supercharge Shell With Python Using Xonsh
#
# Post Link: [Substack](https://avichawla.substack.com/p/supercharge-shell-with-python-using)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:activity:7035921426603720704/)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Read more: https://github.com/xonsh/xonsh
