# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Supercharge value_counts() Method in Pandas With Sidetable
#
#
# Post Link: [Substack](https://avichawla.substack.com/p/supercharge-value_counts-method-in)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/posts/avi-chawla_python-datascience-pandas-activity-7003310443184185344-Vd4u?utm_source=share&utm_medium=member_desktop)

# %%
# !pip install sidetable

# %%
import pandas as pd
import sidetable

# %%
df = pd.read_csv("../_Datasets/employee_dataset.csv")
df.head()
# Out:
#                Name             Company_Name  \
# 0    Johnny Maynard  White, Mcclain and Cobb
# 1  Michael Williams                Scott Inc
# 2       Laura Flynn              Andrade LLC
# 3   Stefanie Archer           James and Sons
# 4     Sierra Garcia             Matthews Inc
#
#                                   Employee_Job_Title      Employee_City  \
# 0                                    Equities trader   New Cindychester
# 1                                    Patent examiner       Ricardomouth
# 2                                    Equities trader  North Melissafurt
# 3                                Retail merchandiser       Ricardomouth
# 4  Armed forces logistics/support/administrative ...       Whitakerbury
#
#   Employee_Country  Employee_Salary Employment_Status  Employee_Rating  \
# 0         Mongolia           764340         Full Time              3.3
# 1    Guinea-Bissau           929230         Full Time              4.6
# ...

# %% [markdown]
# ## Value_counts

# %%
df.Employee_City.value_counts()
# Out:
# West Jamesview       120
# Aliciafort           113
# New Cindychester     106
# Ricardomouth         106
# Whiteside            104
# Kristaburgh           97
# Wardfort              96
# New Russellton        93
# Whitakerbury          87
# North Melissafurt     78
# Name: Employee_City, dtype: int64

# %% [markdown]
# ## Sidetable

# %%
df.stb.freq(["Employee_City"], style = True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_732c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_732c1_level0_col0" class="col_heading level0 col0" >Employee_City</th>
#       <th id="T_732c1_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_732c1_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_732c1_level0_col3" class="col_heading level0 col3" >cumulative_count</th>
#       <th id="T_732c1_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_732c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_732c1_row0_col0" class="data row0 col0" >West Jamesview</td>
#       <td id="T_732c1_row0_col1" class="data row0 col1" >120</td>
#       <td id="T_732c1_row0_col2" class="data row0 col2" >12.00%</td>
#       <td id="T_732c1_row0_col3" class="data row0 col3" >120</td>
# ...
