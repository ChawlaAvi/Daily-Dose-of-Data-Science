# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Are You Sure You Are Using The Correct Pandas Terminologies?
#
# Post Link: [Substack](https://avichawla.substack.com/p/are-you-sure-you-are-using-the-correct)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/feed/update/urn:li:activity:7045708194865647616/)
#
# Twitter Post: [Twitter](https://twitter.com/_avichawla/status/1639943413154848769)

# %% [markdown]
# ![image.png](attachment:image.png)
