# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Explore CSV Data Right From The Terminal
#
#
# Post Link: [Substack](https://avichawla.substack.com/p/explore-csv-data-right-from-the-terminal)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/posts/avi-chawla_python-pandas-datascience-activity-6998229716889468928-crw_?utm_source=share&utm_medium=member_desktop)

# %% [markdown]
# ![image.png](attachment:image.png)
