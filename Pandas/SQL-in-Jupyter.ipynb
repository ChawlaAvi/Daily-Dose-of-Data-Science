# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Use SQL in Jupyter To Analyze A Pandas DataFrame
#
# Post Link: [Substack](https://avichawla.substack.com/p/sql-in-jupyter)

# %%
# !pip install duckdb

# %%
import duckdb
dbcon = duckdb.connect()

# %%
# %load_ext sql

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:memory:

# %%
import pandas as pd

# %%
df = pd.read_csv("../_Datasets/employee_dataset.csv")
df.head()
# Out:
#                Name             Company_Name  \
# 0    Johnny Maynard  White, Mcclain and Cobb
# 1  Michael Williams                Scott Inc
# 2       Laura Flynn              Andrade LLC
# 3   Stefanie Archer           James and Sons
# 4     Sierra Garcia             Matthews Inc
#
#                                   Employee_Job_Title      Employee_City  \
# 0                                    Equities trader   New Cindychester
# 1                                    Patent examiner       Ricardomouth
# 2                                    Equities trader  North Melissafurt
# 3                                Retail merchandiser       Ricardomouth
# 4  Armed forces logistics/support/administrative ...       Whitakerbury
#
#   Employee_Country  Employee_Salary Employment_Status  Employee_Rating  \
# 0         Mongolia           764340         Full Time              3.3
# 1    Guinea-Bissau           929230         Full Time              4.6
# ...

# %%
df[df.Employee_City == "Ricardomouth"]
# Out:
#                  Name                    Company_Name  \
# 1    Michael Williams                       Scott Inc
# 3     Stefanie Archer                  James and Sons
# 46        Jodi Taylor                       Scott Inc
# 52        Kayla Lewis  Campos, Reynolds and Mccormick
# 69       Dillon Davis    Johnston, Fleming and Tanner
# ..                ...                             ...
# 971      Charles West      Wallace, Smith and Shepard
# 978     Jeffrey Davis    Johnston, Fleming and Tanner
# 985       Corey Davis                   Nichols-James
# 992   Tanner Anderson                    Taylor-Ramos
# 993    Erica Robinson  Campos, Reynolds and Mccormick
#
#                                     Employee_Job_Title Employee_City  \
# 1                                      Patent examiner  Ricardomouth
# 3                                  Retail merchandiser  Ricardomouth
# 46                   Sales promotion account executive  Ricardomouth
# ...

# %%
# %%sql
#
# select * from df
# where Employee_City = 'Ricardomouth';
# Out:
#                  Name                    Company_Name  \
# 0    Michael Williams                       Scott Inc
# 1     Stefanie Archer                  James and Sons
# 2         Jodi Taylor                       Scott Inc
# 3         Kayla Lewis  Campos, Reynolds and Mccormick
# 4        Dillon Davis    Johnston, Fleming and Tanner
# ..                ...                             ...
# 101      Charles West      Wallace, Smith and Shepard
# 102     Jeffrey Davis    Johnston, Fleming and Tanner
# 103       Corey Davis                   Nichols-James
# 104   Tanner Anderson                    Taylor-Ramos
# 105    Erica Robinson  Campos, Reynolds and Mccormick
#
#                                     Employee_Job_Title Employee_City  \
# 0                                      Patent examiner  Ricardomouth
# 1                                  Retail merchandiser  Ricardomouth
# 2                    Sales promotion account executive  Ricardomouth
# ...
