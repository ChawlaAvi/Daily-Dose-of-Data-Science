# %% [markdown]
# # Daily-Dose-of-Data-Science
#
# [Daily Dose of Data Science](https://avichawla.substack.com) is a publication on Substack that brings together intriguing frameworks, libraries, technologies, and tips that make the life cycle of a Data Science project effortless.
#
# Author: Avi Chawla
#
# [Medium](https://medium.com/@avi_chawla) | [LinkedIn](https://www.linkedin.com/in/avi-chawla/)
#
# # Stop Analysing Raw Tables. Use Styling Instead!
#
#
# Post Link: [Substack](https://avichawla.substack.com/p/stop-analysing-raw-tables-use-styling)
#
# LinkedIn Post: [LinkedIn](https://www.linkedin.com/posts/avi-chawla_python-datasceince-pandas-activity-6998592901383368704-2IXV?utm_source=share&utm_medium=member_desktop)

# %%
import pandas as pd

# %%
df = pd.read_csv("../_Datasets/DataFrame_Styling_Example.csv")
df.head()
# Out:
#   Currency  Count
# 0      AED   1132
# 1      USD    315
# 2      INR    700
# 3      EUR    522
# 4      SGD    261

# %%
data.style.bar(color='lightgreen',subset='Count')
# Out:
# <style type="text/css">
# #T_c0b5e_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
# }
# #T_c0b5e_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 27.8%, transparent 27.8%);
# }
# #T_c0b5e_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 61.8%, transparent 61.8%);
# }
# #T_c0b5e_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 46.1%, transparent 46.1%);
# }
# #T_c0b5e_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 23.1%, transparent 23.1%);
# }
# #T_c0b5e_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 63.5%, transparent 63.5%);
# }
# #T_c0b5e_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 8.6%, transparent 8.6%);
# }
# #T_c0b5e_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 53.4%, transparent 53.4%);
# }
# ...

# %%
data.style.background_gradient(cmap='Blues',subset='Count')
# Out:
# <style type="text/css">
# #T_92550_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_92550_row1_col1 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_92550_row2_col1 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_92550_row3_col1 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_92550_row4_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_92550_row5_col1 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_92550_row6_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_92550_row7_col1 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_92550_row8_col1 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_92550_row9_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_92550_row10_col1 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_92550_row11_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_92550">
# ...
